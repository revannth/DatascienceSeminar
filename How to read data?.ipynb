# %% [markdown]
# # How to Read Data from various sources?

# %%
import pandas as pd

# %%
data = pd.read_table('https://bit.ly/mtech-worldbankcrisis')
#Normal TSV File
#dir(pd)
data.head(5)
# Out:
#    ?no agr_emp_t_3 agr_emp_t_2 agr_emp_t_1 agr_emp_max agr_emp_index_max  \
# 0  1.0           ?           ?           ?           ?                 ?
# 1  2.0           ?           ?           ?           ?                 ?
# 2  3.0           ?           ?           ?           ?                 ?
# 3  4.0        0.50        0.50        0.50        0.50              0.00
# 4  5.0        0.80        0.70        0.70        0.80              0.00
#
#   agr_emp_min agr_emp_index_min agr_emp_average agr_emp_slope   ...    \
# 0           ?                 ?               ?             ?   ...
# 1           ?                 ?               ?             ?   ...
# 2           ?                 ?               ?             ?   ...
# 3        0.50              0.00            0.50          0.00   ...
# 4        0.70              1.00            0.73         -0.05   ...
#
#   bnk_hlth_t_3 bnk_hlth_t_2 bnk_hlth_t_1 bnk_hlth_max bnk_hlth_index_max  \
# ...

# %%
data.describe()
data.shape
# Out:
# (304, 947)

# %%
pd.read_table('https://bit.ly/movieusers',sep='|',header=None,names=['SNO','Age','Gender','Job','Zipcode'])
#TSV file with Separators
# Out:
#      SNO  Age Gender            Job Zipcode
# 0      1   24      M     technician   85711
# 1      2   53      F          other   94043
# 2      3   23      M         writer   32067
# 3      4   24      M     technician   43537
# 4      5   33      F          other   15213
# 5      6   42      M      executive   98101
# 6      7   57      M  administrator   91344
# 7      8   36      M  administrator   05201
# 8      9   29      M        student   01002
# 9     10   53      M         lawyer   90703
# 10    11   39      F          other   30329
# 11    12   28      F          other   06405
# 12    13   47      M       educator   29206
# 13    14   45      M      scientist   55106
# 14    15   49      F       educator   97301
# 15    16   21      M  entertainment   10309
# 16    17   30      M     programmer   06355
# 17    18   35      F          other   37212
# 18    19   40      M      librarian   02138
# 19    20   42      F      homemaker   95660
# ...

# %%
pd.read_csv('https://bit.ly/mtech-wildlifetrade')
# Out:
#        Year App.                     Taxon        Class             Order  \
# 0      2016    I            Aquila heliaca         Aves     Falconiformes
# 1      2016    I            Aquila heliaca         Aves     Falconiformes
# 2      2016    I      Haliaeetus albicilla         Aves     Falconiformes
# 3      2016    I      Haliaeetus albicilla         Aves     Falconiformes
# 4      2016    I      Haliaeetus albicilla         Aves     Falconiformes
# 5      2016    I      Haliaeetus albicilla         Aves     Falconiformes
# 6      2016    I            Harpia harpyja         Aves     Falconiformes
# 7      2016    I            Harpia harpyja         Aves     Falconiformes
# 8      2016    I            Harpia harpyja         Aves     Falconiformes
# 9      2016    I    Acipenser brevirostrum  Actinopteri  Acipenseriformes
# 10     2016    I          Acipenser sturio  Actinopteri  Acipenseriformes
# 11     2016    I           Ailurus fulgens     Mammalia         Carnivora
# ...
